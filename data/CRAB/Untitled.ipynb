# %%
import numpy as np

data = np.load('SS433_64.npy')

print(data.shape)   # (1, 6, 64, 64)

# data1 = data.squeeze(0)

# print(data1.shape)  # (6, 64, 64)

# np.save('Ruoyu_64_conv400_squeezed.npy', data1)
# Out:
# (3, 64, 64)

# %%
import matplotlib.pyplot as plt

data3 = data[2]
plt.imshow(data3)
print(data3.min())
print(data3.max())
np.save('SS433_64_KM2AE25', data3)
# Out:
# -8.623774
# 75.15303
