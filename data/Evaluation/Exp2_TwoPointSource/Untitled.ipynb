# %%
import numpy as np

# 读取原始数据
data = np.load("EXP2SEP_1000_64_poissonexcess.npy")

print("Original shape:", data.shape)

# 去掉前 200 个样本
data_new = data[200:]

print("New shape:", data_new.shape)

# 保存新数据
np.save("EXP2SEP_800_64_poissonexcess.npy", data_new)

print("Saved to EXP2SEP_800_64_poissonexcess.npy")
# Out:
# Original shape: (1000, 2, 64, 64)
# New shape: (800, 2, 64, 64)
# Saved to EXP2SEP_800_64_poissonexcess.npy
