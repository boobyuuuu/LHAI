# %%
import numpy as np

data = np.load("xinyu_31000_32_train_v1.npy")

print(data.shape)

data1 = data[0,0:1000,:,:]

print(data1.shape)

np.save("xinyu_1000_64.npy", data1)
# Out:
# (2, 31000, 32, 32)
# (1000, 32, 32)
