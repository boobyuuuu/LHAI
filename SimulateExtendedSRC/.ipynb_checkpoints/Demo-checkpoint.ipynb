# %%
from response import *
# Out:
# 18:43:06 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=885166;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=651810;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/astromodels/functions/functions_1D/functions.py#47\47]8;;\
#                   available
#          WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=845371;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=674117;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/astromodels/functions/functions_1D/functions.py#68\68]8;;\
#                   will not be available.
# 18:43:07 WARNING   The ebltable package is not available. Models that depend on it will not be     ]8;id=374201;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/astromodels/functions/functions_1D/absorption.py\absorption.py]8;;\:]8;id=939007;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/astromodels/functions/functions_1D/absorption.py#33\33]8;;\
#                   available
#          INFO      Starting 3ML!                                                                     ]8;id=310475;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=567661;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/__init__.py#39\39]8;;\
#          WARNING   WARNINGs here are NOT errors                                                      ]8;id=511837;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=569634;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/__init__.py#40\40]8;;\
#          WARNING   but are inform you about optional packages that can be installed                  ]8;id=619356;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=533729;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/__init__.py#41\41]8;;\
#          WARNING    to disable these messages, turn off start_warning in your config file            ]8;id=599688;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=217798;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/__init__.py#44\44]8;;\
#          WARNING   no display variable set. using backend for graphics without display (agg)         ]8;id=431265;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=232679;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/__init__.py#50\50]8;;\
# 18:43:07 WARNING   ROOT minimizer not available                                                ]8;id=460107;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=483485;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/minimizer/minimization.py#1345\1345]8;;\
#          WARNING   Multinest minimizer not available                                           ]8;id=486634;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=608241;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/minimizer/minimization.py#1357\1357]8;;\
#          WARNING   PyGMO is not available                                                      ]8;id=430283;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=520110;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/minimizer/minimization.py#1369\1369]8;;\
#          WARNING   The cthreeML package is not installed. You will not be able to use plugins which  ]8;id=354463;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=782605;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/__init__.py#94\94]8;;\
#                   require the C/C++ interface (currently HAWC)
#          WARNING   Could not import plugin HAWCLike.py. Do you have the relative instrument         ]8;id=275043;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=396928;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
#          WARNING   Could not import plugin FermiLATLike.py. Do you have the relative instrument     ]8;id=371212;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=680823;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
# 18:43:08 WARNING   No fermitools installed                                              ]8;id=811910;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py\lat_transient_builder.py]8;;\:]8;id=122233;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py#44\44]8;;\

# %%
fitsfile = './Einstein.fits'
map_tree = '../res_file/map_20240731_WCDA.root'
det_res = '../res_file/res_20240731_WCDA.root'
mapname = './data/Einstein.hd5'

from scipy.special import k0

def diffusion(cx, cy, theta, e, width ,pw, xsize):
    '''
    cx, cy: center, float, 0-1
    '''
    src = np.zeros((xsize, xsize))
    x = np.arange(xsize)*pw
    ix = np.arange(xsize)
    xx,yy=np.meshgrid(x,x)
    cpx = np.interp(cx, ix/xsize, x)+ np.pi* 1e-2
    cpy = np.interp(cy, ix/xsize, x)+ np.pi* 1e-2
    rr = np.sqrt(((xx-cpx) * np.cos(theta) + (yy-cpy) * np.sin(theta))**2 +
                 e* (-(xx-cpx) * np.sin(theta) + (yy-cpy) * np.cos(theta))**2)
    src = np.exp( -rr/width)* k0(rr)
    srcsum = src.sum()
    assert np.isfinite(srcsum), "Sum must be finite"
    
    return src/srcsum * (pw/180 * np.pi)**2

data = diffusion(np.random.uniform(0.5,0.52),np.random.uniform(0.5,0.52),0,1,2.2,0.1,150)

print(data.shape) # random map

xsize = 64  # size of final blurred array 
# Create fits file with 2darray
data2fits(data, 150, 10, fitsfile, xsize_fin = xsize, pixelw = 0.1)
# Now the fits file is saved.
# Out:
# (150, 150)

# %%
# Perform detres simulation
# %matplotlib inline
img = respconv(
    fitsfile, map_tree, det_res, mapname,
    xsize, srcname='src',
    plindex=2.63, piv=1e9, specK=2e-25,
    bins='0'
        )
# Out:
# 18:43:10 INFO      Using transits contained in maptree                                                    ]8;id=91989;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/hawc_hal/HAL.py\HAL.py]8;;\:]8;id=31814;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/hawc_hal/HAL.py#77\77]8;;\
#          INFO      Reading Maptree!                                                           ]8;id=762687;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/hawc_hal/maptree/from_root_file.py\from_root_file.py]8;;\:]8;id=266317;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/hawc_hal/maptree/from_root_file.py#234\234]8;;\
# 18:43:19 INFO      Creating singleton for                                                            ]8;id=471054;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/hawc_hal/response/response.py\response.py]8;;\:]8;id=279214;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/hawc_hal/response/response.py#49\49]8;;\
#                   /home/innov2021/GXW/WCDA/SimulateExtendedSRC/../res_file/res_20240731_WCDA.root
# 18:43:28 INFO      Considering 17 dec bins for extended source src                  ]8;id=525531;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/hawc_hal/convolved_source/convolved_extended_source.py\convolved_extended_source.py]8;;\:]8;id=956016;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/hawc_hal/convolved_source/convolved_extended_source.py#71\71]8;;\
#          INFO      Central bin is bin at Declination = 10.013                       ]8;id=311352;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/hawc_hal/convolved_source/convolved_extended_source.py\convolved_extended_source.py]8;;\:]8;id=996425;file:///home/innov2021/miniconda3/envs/3ml/lib/python3.11/site-packages/hawc_hal/convolved_source/convolved_extended_source.py#80\80]8;;\

# %%
plt.imshow(img)
